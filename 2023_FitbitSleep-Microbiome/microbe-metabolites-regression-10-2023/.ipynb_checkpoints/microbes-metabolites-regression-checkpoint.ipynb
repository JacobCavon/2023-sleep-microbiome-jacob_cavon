# %%
import pandas as pd
import json
from arivale_data_interface import get_snapshot
import warnings
warnings.simplefilter("ignore")

#import the df and the feature indices

sleep_merged = pd.read_csv('../sleep_microbe_metabolite_df/sleep_microbes_metabolites_df.csv')

with open('../sleep_microbe_metabolite_df/activity_features.json', 'r') as f:
    activity_features = json.load(f)
with open('../sleep_microbe_metabolite_df/metabolite_features.json', 'r') as f:
    metabolite_features = json.load(f)
with open('../sleep_microbe_metabolite_df/sleep_features.json', 'r') as f:
    sleep_features = json.load(f)
with open('../sleep_microbe_metabolite_df/microbe_features.json', 'r') as f:
    microbe_features = json.load(f)

# %%
# Make binary categorical variable for Adlercreutzia abundance
# If present (ie abundance greater than 0) then 1
# otherwise if no abundance detected (ie 0), then entry is 0
sleep_merged['adlercreutzia_binary'] = sleep_merged['bacteria_actinobacteria_coriobacteriia_coriobacteriales_coriobacteriaceae_adlercreutzia'].apply(lambda x: 0 if x == 0 else 1)

# %%
import scipy
import numpy as np

#centered log ratio transform the microbe columns
sleep_merged[microbe_features] = sleep_merged[microbe_features].replace(0, 0.0000001)
#sleep_merged[microbe_features] = sleep_merged[microbe_features].replace(0, np.nan)
sleep_merged['gmean'] = sleep_merged[microbe_features].apply(scipy.stats.mstats.gmean, axis=1, nan_policy='propagate')
sleep_merged[microbe_features] = np.log(sleep_merged[microbe_features].divide(sleep_merged['gmean'], axis=0))
sleep_merged.drop(columns='gmean', inplace=True)
sleep_merged.reset_index(inplace=True)

#log transform the metabolite columns
sleep_merged[metabolite_features] = np.log(sleep_merged[metabolite_features])

#log transform the sleep columns
sleep_merged[sleep_features] = np.log(sleep_merged[sleep_features])

#log transform the activity columns
sleep_merged[activity_features] = np.log(sleep_merged[activity_features])

# %% [markdown]
# #### Metabolites and Microbes that are significantly associated with Sleep Efficiency

# %%
metabolite_hits = ['metabolite_100001167',
 'metabolite_100001597',
 'metabolite_100004295',
 'metabolite_999953267',
 'metabolite_999946701',
 'metabolite_999933132',
 'metabolite_999947670',
 'metabolite_100009005',
 'metabolite_999946283',
 'metabolite_999948081',
 'metabolite_999946690',
 'metabolite_1022',
 'metabolite_234',
 'metabolite_100006367',
 'metabolite_999952640',
 'metabolite_999946398',
 'metabolite_100001399',
 'metabolite_100001651',
 'metabolite_999947802',
 'metabolite_100000997',
 'metabolite_100000773',
 'metabolite_100003169']

# %%
microbe_hits = ['bacteria_actinobacteria_coriobacteriia_coriobacteriales_coriobacteriaceae_adlercreutzia',
 'bacteria_firmicutes_erysipelotrichi_erysipelotrichales_erysipelotrichaceae']

# %% [markdown]
# #### Metabolites that are significantly associated with any sleep measure

# %%
metabolite_hits_any_sleep = ['metabolite_999949512',
 'metabolite_100000808',
 'metabolite_999952501',
 'metabolite_100000808',
 'metabolite_1023',
 'metabolite_197',
 'metabolite_100015837',
 'metabolite_197',
 'metabolite_100002528',
 'metabolite_197',
 'metabolite_100021707',
 'metabolite_100000808',
 'metabolite_913',
 'metabolite_100001437',
 'metabolite_823',
 'metabolite_999949512',
 'metabolite_100008989',
 'metabolite_100021707',
 'metabolite_100015840',
 'metabolite_100004552',
 'metabolite_1023',
 'metabolite_100015837',
 'metabolite_100000827',
 'metabolite_491',
 'metabolite_100015840',
 'metabolite_999949512',
 'metabolite_100000787',
 'metabolite_331',
 'metabolite_823',
 'metabolite_100005351',
 'metabolite_100000269',
 'metabolite_100008916',
 'metabolite_482',
 'metabolite_100004295',
 'metabolite_100021707',
 'metabolite_100001167',
 'metabolite_100021324',
 'metabolite_100021324',
 'metabolite_100019794',
 'metabolite_100000008',
 'metabolite_100000808',
 'metabolite_297',
 'metabolite_100000008',
 'metabolite_1140',
 'metabolite_999949512',
 'metabolite_491',
 'metabolite_100009376',
 'metabolite_100003151',
 'metabolite_100009143',
 'metabolite_100009146',
 'metabolite_313',
 'metabolite_491',
 'metabolite_100001178',
 'metabolite_100015831',
 'metabolite_999952501',
 'metabolite_100001272',
 'metabolite_913',
 'metabolite_1026',
 'metabolite_100000787',
 'metabolite_2050',
 'metabolite_331',
 'metabolite_100000008',
 'metabolite_100021707',
 'metabolite_1023',
 'metabolite_100000626',
 'metabolite_482',
 'metabolite_100008915',
 'metabolite_100001570',
 'metabolite_1224',
 'metabolite_100001501',
 'metabolite_100008916',
 'metabolite_1224',
 'metabolite_100009138',
 'metabolite_279',
 'metabolite_100000787',
 'metabolite_35',
 'metabolite_100001597',
 'metabolite_35',
 'metabolite_100022009',
 'metabolite_100000900',
 'metabolite_100004328',
 'metabolite_100004295',
 'metabolite_100015839',
 'metabolite_1539',
 'metabolite_999946636',
 'metabolite_823',
 'metabolite_234',
 'metabolite_100000039',
 'metabolite_100009125',
 'metabolite_999946261',
 'metabolite_100009378',
 'metabolite_100009161',
 'metabolite_100021123',
 'metabolite_171',
 'metabolite_100002871',
 'metabolite_999947670',
 'metabolite_913',
 'metabolite_100008984',
 'metabolite_512',
 'metabolite_444',
 'metabolite_535',
 'metabolite_100000827',
 'metabolite_100021324',
 'metabolite_100021123',
 'metabolite_100021324',
 'metabolite_278',
 'metabolite_999946261',
 'metabolite_100015838',
 'metabolite_100003151',
 'metabolite_100015839',
 'metabolite_331',
 'metabolite_100001556',
 'metabolite_100001272',
 'metabolite_100000827',
 'metabolite_498',
 'metabolite_100001571',
 'metabolite_100009148',
 'metabolite_100020515',
 'metabolite_100002060',
 'metabolite_999946620',
 'metabolite_999953267',
 'metabolite_100010935',
 'metabolite_100008992',
 'metabolite_100000276',
 'metabolite_100001501',
 'metabolite_313',
 'metabolite_821',
 'metabolite_297',
 'metabolite_100020515',
 'metabolite_100000639',
 'metabolite_100015683',
 'metabolite_999952483',
 'metabolite_100000039',
 'metabolite_504',
 'metabolite_100009138',
 'metabolite_171',
 'metabolite_999946516',
 'metabolite_999946601',
 'metabolite_100001501',
 'metabolite_100009209',
 'metabolite_999946701',
 'metabolite_100005466',
 'metabolite_100009143',
 'metabolite_999946354',
 'metabolite_100001446',
 'metabolite_100004328',
 'metabolite_999933132',
 'metabolite_100001511',
 'metabolite_100015840',
 'metabolite_100000900',
 'metabolite_100001485',
 'metabolite_100015836',
 'metabolite_100022008',
 'metabolite_999947670',
 'metabolite_197',
 'metabolite_100001569',
 'metabolite_50',
 'metabolite_100009378',
 'metabolite_100004328',
 'metabolite_100008919',
 'metabolite_50',
 'metabolite_331',
 'metabolite_999952483',
 'metabolite_100009005',
 'metabolite_999949679',
 'metabolite_913',
 'metabolite_999952501',
 'metabolite_100004295',
 'metabolite_100000827',
 'metabolite_100001126',
 'metabolite_800',
 'metabolite_100009038',
 'metabolite_100009143',
 'metabolite_100003397',
 'metabolite_50',
 'metabolite_1235',
 'metabolite_999952909',
 'metabolite_100005384',
 'metabolite_100001674',
 'metabolite_1539',
 'metabolite_1021',
 'metabolite_100006314',
 'metabolite_100021123',
 'metabolite_100001395',
 'metabolite_100009376',
 'metabolite_100009000',
 'metabolite_100009335',
 'metabolite_1026',
 'metabolite_999946283',
 'metabolite_100015831',
 'metabolite_100009142',
 'metabolite_100009232',
 'metabolite_999946636',
 'metabolite_100003271',
 'metabolite_100002528',
 'metabolite_999947802',
 'metabolite_100009406',
 'metabolite_100009000',
 'metabolite_100001511',
 'metabolite_100022004',
 'metabolite_999948081',
 'metabolite_212',
 'metabolite_100009139',
 'metabolite_100001383',
 'metabolite_100000257',
 'metabolite_100000776',
 'metabolite_100002528',
 'metabolite_482',
 'metabolite_35',
 'metabolite_100006298',
 'metabolite_100006056',
 'metabolite_266',
 'metabolite_1539',
 'metabolite_100020893',
 'metabolite_821',
 'metabolite_100021760',
 'metabolite_100009148',
 'metabolite_100001571',
 'metabolite_100001566',
 'metabolite_888',
 'metabolite_100009038',
 'metabolite_100001485',
 'metabolite_100000639',
 'metabolite_100005673',
 'metabolite_100020241',
 'metabolite_100008916',
 'metabolite_999933140',
 'metabolite_100015618',
 'metabolite_999953157',
 'metabolite_999946690',
 'metabolite_1518',
 'metabolite_999953157',
 'metabolite_100001211',
 'metabolite_100001586',
 'metabolite_297',
 'metabolite_100005350',
 'metabolite_100009019',
 'metabolite_100001112',
 'metabolite_100009139',
 'metabolite_356',
 'metabolite_1022',
 'metabolite_100009125',
 'metabolite_234',
 'metabolite_999946511',
 'metabolite_100008991',
 'metabolite_1489',
 'metabolite_100001562',
 'metabolite_100022006',
 'metabolite_100000269',
 'metabolite_100009347',
 'metabolite_100022120',
 'metabolite_512',
 'metabolite_313',
 'metabolite_999946633',
 'metabolite_100001552',
 'metabolite_100006367',
 'metabolite_100000665',
 'metabolite_100000008',
 'metabolite_100009225',
 'metabolite_100020371',
 'metabolite_100001294',
 'metabolite_100009125',
 'metabolite_100001313',
 'metabolite_999952640',
 'metabolite_279',
 'metabolite_100006051',
 'metabolite_100000039',
 'metabolite_100009331',
 'metabolite_100009347',
 'metabolite_100001541',
 'metabolite_100000276',
 'metabolite_100009005',
 'metabolite_100001437',
 'metabolite_100021329',
 'metabolite_999946398',
 'metabolite_1113',
 'metabolite_100008903',
 'metabolite_100022005',
 'metabolite_100001586',
 'metabolite_100006115',
 'metabolite_100001563',
 'metabolite_100004328',
 'metabolite_999946632',
 'metabolite_100020487',
 'metabolite_100001597',
 'metabolite_999947820',
 'metabolite_100005384',
 'metabolite_100002537',
 'metabolite_100000672',
 'metabolite_100022120',
 'metabolite_100008992',
 'metabolite_100008984',
 'metabolite_100009225',
 'metabolite_999947670',
 'metabolite_100002173',
 'metabolite_999946261',
 'metabolite_100008992',
 'metabolite_100001399',
 'metabolite_100001651',
 'metabolite_100001409',
 'metabolite_100005996',
 'metabolite_100002528',
 'metabolite_100009146',
 'metabolite_100001270',
 'metabolite_1026',
 'metabolite_100001614',
 'metabolite_999947802',
 'metabolite_100000706',
 'metabolite_100020893',
 'metabolite_100001433',
 'metabolite_100005673',
 'metabolite_100000639',
 'metabolite_273',
 'metabolite_100001552',
 'metabolite_100006614',
 'metabolite_100022003',
 'metabolite_100001776',
 'metabolite_100000900',
 'metabolite_100015840',
 'metabolite_100009146',
 'metabolite_1021',
 'metabolite_100000269',
 'metabolite_100005367',
 'metabolite_100002027',
 'metabolite_100009051',
 'metabolite_100009140',
 'metabolite_100001810',
 'metabolite_999952501',
 'metabolite_100001022',
 'metabolite_100009345',
 'metabolite_100000997',
 'metabolite_1628',
 'metabolite_100000997',
 'metabolite_100015792',
 'metabolite_100021666',
 'metabolite_504',
 'metabolite_100000263',
 'metabolite_1004',
 'metabolite_62',
 'metabolite_100001106',
 'metabolite_100009066',
 'metabolite_100000773',
 'metabolite_100003169',
 'metabolite_100009233',
 'metabolite_100022003',
 'metabolite_100003169',
 'metabolite_100009335']

# %% [markdown]
# # Regression Microbes-Metabolites any sleep hits w/ sex, age, BMI, and activity covariates

# %%
from rich.progress import track
from statsmodels.formula.api import ols
from statsmodels.stats.multitest import multipletests

def get_results(dependent_feature, independent_feature):
    """Get a single association for a specific combination of features."""
    # Define the formula using the provided dependent and independent variables
    activity_covariates = ' + '.join(activity_features)
    formula = f"{dependent_feature} ~ C(sex) + age + BMI_CALC + C(vendor) + {activity_covariates} + {independent_feature}"
    fitted = ols(formula, data=df).fit()
    
    # Create a Series with the results
    result_series = pd.Series({
        "dependent_feature": dependent_feature,
        "independent_feature": independent_feature,
        "beta": fitted.params[independent_feature],
        "t_statistic": fitted.tvalues[independent_feature],
        "p": fitted.pvalues[independent_feature],
        "n": fitted.nobs
    })

    return result_series

# %%
df = sleep_merged

# Define your lists of features
dependent_features = metabolite_hits_any_sleep
independent_features = microbe_hits

# Initialize an empty list to store the results
all_results = []

# Iterate through all combinations of dependent and independent features
for dependent_feature in track(dependent_features, description="Dependent Features"):
    for independent_feature in independent_features:
        result = get_results(dependent_feature, independent_feature)
        all_results.append(result)

# turn the all_results list into a pandas df
tests = pd.DataFrame(pd.concat(all_results, axis=1))
tests = tests.transpose()

# add the metabolite metadata and calculate corrected p-value, q
anns = get_snapshot("metabolomics_metadata").iloc[:, 0:8]
anns["dependent_feature"] = "metabolite_" + anns.CHEMICAL_ID.astype(str)
tests = pd.merge(tests, anns, on="dependent_feature")
tests["q"] = multipletests(tests["p"], method="fdr_bh")[1]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
tests.to_csv('microbes_and_metabolites_any_sleep_regression.csv', index=False)

# %%
tests[tests.SUB_PATHWAY == 'Steroid']
# Out:
#         dependent_feature                                independent_feature  \
# 550        metabolite_356  bacteria_actinobacteria_coriobacteriia_corioba...
# 551        metabolite_356  bacteria_firmicutes_erysipelotrichi_erysipelot...
# 642        metabolite_273  bacteria_actinobacteria_coriobacteriia_corioba...
# 643        metabolite_273  bacteria_firmicutes_erysipelotrichi_erysipelot...
# 654  metabolite_100002027  bacteria_actinobacteria_coriobacteriia_corioba...
# 655  metabolite_100002027  bacteria_firmicutes_erysipelotrichi_erysipelot...
#
#          beta t_statistic         p       n  CHEMICAL_ID SUB_PATHWAY  \
# 550  0.000057    0.018893  0.984928  2210.0          356     Steroid
# 551  0.022189    2.815841  0.004908  2210.0          356     Steroid
# 642 -0.001886   -0.960576  0.336871  2216.0          273     Steroid
# 643   0.02075    4.081287  0.000046  2216.0          273     Steroid
# 654 -0.003295   -0.722957  0.469784  2184.0    100002027     Steroid
# ...

# %% [markdown]
# # Regression Microbes-Metabolites Sleep_efficiency Hits w/ sex, age, and BMI

# %%
from rich.progress import track
from statsmodels.formula.api import ols
from statsmodels.stats.multitest import multipletests

def get_results(dependent_feature, independent_feature):
    """Get a single association for a specific combination of features."""
    # Define the formula using the provided dependent and independent variables
    formula = f"{dependent_feature} ~ C(sex) + age + BMI_CALC + C(vendor) + {independent_feature}"
    fitted = ols(formula, data=df).fit()
    
    # Create a Series with the results
    result_series = pd.Series({
        "dependent_feature": dependent_feature,
        "independent_feature": independent_feature,
        "beta": fitted.params[independent_feature],
        "t_statistic": fitted.tvalues[independent_feature],
        "p": fitted.pvalues[independent_feature],
        "n": fitted.nobs
    })

    return result_series

# %%
df = sleep_merged

# Define your lists of features
dependent_features = metabolite_hits
independent_features = microbe_hits

# Initialize an empty list to store the results
all_results = []

# Iterate through all combinations of dependent and independent features
for dependent_feature in track(dependent_features, description="Dependent Features"):
    for independent_feature in independent_features:
        result = get_results(dependent_feature, independent_feature)
        all_results.append(result)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
# turn the all_results list into a pandas df
tests = pd.DataFrame(pd.concat(all_results, axis=1))
tests = tests.transpose()

# add the metabolite metadata and calculate corrected p-value, q
anns = get_snapshot("metabolomics_metadata").iloc[:, 0:8]
anns["dependent_feature"] = "metabolite_" + anns.CHEMICAL_ID.astype(str)
tests = pd.merge(tests, anns, on="dependent_feature")
tests["q"] = multipletests(tests["p"], method="fdr_bh")[1]

# %%
# save the results to a csv
tests.to_csv('microbes_and_metabolites_regression_CLR_wZeroImpute_woActivityCovariates.csv', index=False)

# %% [markdown]
# # Regression Microbes-Metabolites Sleep_efficiency Hits w/ sex, age, BMI, and activity covariates

# %%
from rich.progress import track
from statsmodels.formula.api import ols
from statsmodels.stats.multitest import multipletests

def get_results(dependent_feature, independent_feature):
    """Get a single association for a specific combination of features."""
    # Define the formula using the provided dependent and independent variables
    activity_covariates = ' + '.join(activity_features)
    formula = f"{dependent_feature} ~ C(sex) + age + BMI_CALC + C(vendor) + {activity_covariates} + {independent_feature}"
    fitted = ols(formula, data=df).fit()
    
    # Create a Series with the results
    result_series = pd.Series({
        "dependent_feature": dependent_feature,
        "independent_feature": independent_feature,
        "beta": fitted.params[independent_feature],
        "t_statistic": fitted.tvalues[independent_feature],
        "p": fitted.pvalues[independent_feature],
        "n": fitted.nobs
    })

    return result_series

# %%
df = sleep_merged

# Define your lists of features
dependent_features = metabolite_hits
independent_features = microbe_hits

# Initialize an empty list to store the results
all_results = []

# Iterate through all combinations of dependent and independent features
for dependent_feature in track(dependent_features, description="Dependent Features"):
    for independent_feature in independent_features:
        result = get_results(dependent_feature, independent_feature)
        all_results.append(result)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
# turn the all_results list into a pandas df
tests = pd.DataFrame(pd.concat(all_results, axis=1))
tests = tests.transpose()

# add the metabolite metadata and calculate corrected p-value, q
anns = get_snapshot("metabolomics_metadata").iloc[:, 0:8]
anns["dependent_feature"] = "metabolite_" + anns.CHEMICAL_ID.astype(str)
tests = pd.merge(tests, anns, on="dependent_feature")
tests["q"] = multipletests(tests["p"], method="fdr_bh")[1]

# %%
# save the results to a csv
tests.to_csv('microbes_and_metabolites_regression_CLR_wZeroImpute_wActivityCovariates.csv', index=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = sleep_merged.copy()
df = df.rename(columns={'metabolite_100001399': '1,7-dimethylurate', 'bacteria_actinobacteria_coriobacteriia_coriobacteriales_coriobacteriaceae_adlercreutzia' : 'adlercreutzia'})
features = ['sleep_efficiency', '1,7-dimethylurate', 'adlercreutzia']

g = sns.pairplot(df[features])
g.map_upper(sns.histplot, color='purple')
plt.show()

# %% [markdown]
# # Retained microbe-metabolite sleep_efficiency hits after adding Activity covariates

# %%
import pandas as pd
import numpy as np

tests_woActivity = pd.read_csv('microbes_and_metabolites_regression_CLR_wZeroImpute_woActivityCovariates.csv')
tests_woActivity = tests_woActivity[tests_woActivity.q < 0.05].sort_values(by='q')
tests_wActivity = pd.read_csv('microbes_and_metabolites_regression_CLR_wZeroImpute_wActivityCovariates.csv')
tests_wActivity = tests_wActivity[tests_wActivity.q < 0.05].sort_values(by='q')

# %%
common_rows = pd.merge(tests_woActivity, tests_wActivity, on=['independent_feature', 'dependent_feature'], how='inner')

# %%
tests_wActivity
# Out:
#        dependent_feature                                independent_feature  \
# 4   metabolite_100004295  bacteria_actinobacteria_coriobacteriia_corioba...
# 20  metabolite_999946690  bacteria_actinobacteria_coriobacteriia_corioba...
# 28  metabolite_999952640  bacteria_actinobacteria_coriobacteriia_corioba...
# 24        metabolite_234  bacteria_actinobacteria_coriobacteriia_corioba...
# 21  metabolite_999946690  bacteria_firmicutes_erysipelotrichi_erysipelot...
# 29  metabolite_999952640  bacteria_firmicutes_erysipelotrichi_erysipelot...
# 32  metabolite_100001399  bacteria_actinobacteria_coriobacteriia_corioba...
# 34  metabolite_100001651  bacteria_actinobacteria_coriobacteriia_corioba...
# 40  metabolite_100000773  bacteria_actinobacteria_coriobacteriia_corioba...
# 26  metabolite_100006367  bacteria_actinobacteria_coriobacteriia_corioba...
# 6   metabolite_999953267  bacteria_actinobacteria_coriobacteriia_corioba...
# ...

# %%
adler = tests_wActivity[tests_wActivity.BIOCHEMICAL_NAME == '1,7-dimethylurate']

# %%
adler
# Out:
#        dependent_feature                                independent_feature  \
# 32  metabolite_100001399  bacteria_actinobacteria_coriobacteriia_corioba...
#
#         beta  t_statistic        p       n  CHEMICAL_ID          SUB_PATHWAY  \
# 32  0.030059     3.648845  0.00027  2120.0    100001399  Xanthine Metabolism
#
#    SUPER_PATHWAY   BIOCHEMICAL_NAME         CAS    KEGG       HMDB  PUBCHEM  \
# 32   Xenobiotics  1,7-dimethylurate  33868-03-0  C16356  HMDB11103  91611.0
#
#            q
# 32  0.001696

# %%
tests_wActivity[tests_wActivity.independent_feature == 'bacteria_actinobacteria_coriobacteriia_coriobacteriales_coriobacteriaceae_adlercreutzia']
# Out:
#        dependent_feature                                independent_feature  \
# 4   metabolite_100004295  bacteria_actinobacteria_coriobacteriia_corioba...
# 20  metabolite_999946690  bacteria_actinobacteria_coriobacteriia_corioba...
# 28  metabolite_999952640  bacteria_actinobacteria_coriobacteriia_corioba...
# 24        metabolite_234  bacteria_actinobacteria_coriobacteriia_corioba...
# 32  metabolite_100001399  bacteria_actinobacteria_coriobacteriia_corioba...
# 34  metabolite_100001651  bacteria_actinobacteria_coriobacteriia_corioba...
# 40  metabolite_100000773  bacteria_actinobacteria_coriobacteriia_corioba...
# 26  metabolite_100006367  bacteria_actinobacteria_coriobacteriia_corioba...
# 6   metabolite_999953267  bacteria_actinobacteria_coriobacteriia_corioba...
# 16  metabolite_999946283  bacteria_actinobacteria_coriobacteriia_corioba...
#
#         beta  t_statistic             p       n  CHEMICAL_ID  \
# 4  -0.068918    -8.952143  7.524697e-19  2101.0    100004295
# ...

# %%
tests_wActivity.sort_values(by='SUPER_PATHWAY').sort_values(by='independent_feature')
# Out:
#        dependent_feature                                independent_feature  \
# 24        metabolite_234  bacteria_actinobacteria_coriobacteriia_corioba...
# 34  metabolite_100001651  bacteria_actinobacteria_coriobacteriia_corioba...
# 40  metabolite_100000773  bacteria_actinobacteria_coriobacteriia_corioba...
# 26  metabolite_100006367  bacteria_actinobacteria_coriobacteriia_corioba...
# 4   metabolite_100004295  bacteria_actinobacteria_coriobacteriia_corioba...
# 32  metabolite_100001399  bacteria_actinobacteria_coriobacteriia_corioba...
# 20  metabolite_999946690  bacteria_actinobacteria_coriobacteriia_corioba...
# 28  metabolite_999952640  bacteria_actinobacteria_coriobacteriia_corioba...
# 6   metabolite_999953267  bacteria_actinobacteria_coriobacteriia_corioba...
# 16  metabolite_999946283  bacteria_actinobacteria_coriobacteriia_corioba...
# 1   metabolite_100001167  bacteria_firmicutes_erysipelotrichi_erysipelot...
# ...

# %% [markdown]
# 1,7-Dimethyluric acid is a metabolite of caffeine (Item No. 14118) produced by the action of xanthine oxidase on paraxanthine. It can be detected in urine as a biomarker of caffeine consumption.
# https://www.caymanchem.com/product/19584/1%2C7-dimethyluric-acid
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4408171/#:~:text=The%20recent%20discovery%20of%20bacterial,opens%20numerous%20potential%20biotechnological%20applications.
#
# ![Pathways-for-the-caffeine-metabolism-and-implication-of-human-cytochrome-enzymes-CYP.png](attachment:1e6b8bd0-ae10-487e-a32d-556b869845f2.png)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame, and you want to plot each column against "sleep_efficiency"
g = sns.lmplot(x='bacteria_actinobacteria_coriobacteriia_coriobacteriales_coriobacteriaceae_adlercreutzia', y='sleep_efficiency', data=sleep_merged, scatter_kws={'alpha':0.1}, ci=95, fit_reg=True, line_kws={'color': 'red'})
plt.title(f'Scatter Plot: Adlercreutzia vs. Sleep Efficiency')
plt.show()

# %% [markdown]
# # 2-piperidinone associated with sleep efficiency

# %%
from rich.progress import track
from statsmodels.formula.api import ols
from statsmodels.stats.multitest import multipletests

def get_results(dependent_feature, independent_feature):
    """Get a single association for a specific combination of features."""
    # Define the formula using the provided dependent and independent variables
    activity_covariates = ' + '.join(activity_features)
    formula = f"{dependent_feature} ~ C(sex) + age + BMI_CALC + {activity_covariates} + {independent_feature}"
    fitted = ols(formula, data=df).fit()
    
    # Create a Series with the results
    result_series = pd.Series({
        "dependent_feature": dependent_feature,
        "independent_feature": independent_feature,
        "beta": fitted.params[independent_feature],
        "t_statistic": fitted.tvalues[independent_feature],
        "p": fitted.pvalues[independent_feature],
        "n": fitted.nobs
    })

    return result_series

# %%
df = pd.read_csv('sleep_df_piperidinone2.csv')

# %%
df = sleep_merged
#df = pd.read_csv('sleep_df_piperidinone2.csv')

# Define your lists of features
dependent_features = ['sleep_efficiency']
independent_features = ['metabolite_100004295'] # 2-piperidinone
#independent_features = ['piperidinone2']
#independent_features = ['bacteria_actinobacteria_coriobacteriia_coriobacteriales_coriobacteriaceae_adlercreutzia']

# Initialize an empty list to store the results
all_results = []

# Iterate through all combinations of dependent and independent features
for dependent_feature in track(dependent_features, description="Dependent Features"):
    for independent_feature in independent_features:
        result = get_results(dependent_feature, independent_feature)
        all_results.append(result)

# concatenate each entry in all_results list and turn into a pandas DF
tests = pd.DataFrame(pd.concat(all_results, axis=1))
tests = tests.transpose()

# add the metabolite metadata and calculate corrected p-value, q
#anns = get_snapshot("metabolomics_metadata").iloc[:, 0:8]
#anns["independent_feature"] = "metabolite_" + anns.CHEMICAL_ID.astype(str)
#tests = pd.merge(tests, anns, on="independent_feature")
#tests["q"] = multipletests(tests["p"], method="fdr_bh")[1]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
tests
# Out:
#   dependent_feature   independent_feature     beta t_statistic         p  \
# 0  sleep_efficiency  metabolite_100004295 -0.18433   -4.227416  0.000025
#
#         n
# 0  2049.0

# %%
tests
# Out:
#   dependent_feature   independent_feature     beta t_statistic         p  \
# 0  sleep_efficiency  metabolite_100004295 -0.18433   -4.227416  0.000025
#
#         n
# 0  2049.0

# %%
tests
# Out:
#   dependent_feature                                independent_feature  \
# 0  sleep_efficiency  bacteria_actinobacteria_coriobacteriia_corioba...
#
#       beta t_statistic         p       n
# 0  0.05605    3.557824  0.000383  2049.0

# %%
tests
# Out:
#   dependent_feature                                independent_feature  \
# 0  sleep_efficiency  bacteria_actinobacteria_coriobacteriia_corioba...
#
#        beta t_statistic         p       n
# 0  0.000719     4.29451  0.000018  1974.0

# %%
tests
# Out:
#   dependent_feature independent_feature      beta t_statistic         p  \
# 0  sleep_efficiency       piperidinone2 -0.001819    -3.88528  0.000106
#
#         n
# 0  1974.0

# %%
tests
# Out:
#   dependent_feature                                independent_feature  \
# 0  sleep_efficiency  bacteria_actinobacteria_coriobacteriia_corioba...
#
#        beta t_statistic         p       n
# 0  0.000719     4.29451  0.000018  1974.0

# %%
tests
# Out:
#   dependent_feature                                independent_feature  \
# 0  sleep_efficiency  bacteria_actinobacteria_coriobacteriia_corioba...
#
#        beta t_statistic         p       n
# 0  0.000614    3.602245  0.000323  1974.0

# %%
tests
# Out:
#   dependent_feature   independent_feature      beta t_statistic         p  \
# 0  sleep_efficiency  metabolite_100004295 -0.001964   -4.234255  0.000024
#
#         n  CHEMICAL_ID           SUB_PATHWAY SUPER_PATHWAY BIOCHEMICAL_NAME  \
# 0  2049.0    100004295  Food Component/Plant   Xenobiotics   2-piperidinone
#
#         CAS KEGG       HMDB  PUBCHEM         q
# 0  675-20-7  NaN  HMDB11749  12665.0  0.000024

# %% [markdown]
# # Regression of 2-piperidinone on 1,7-dimethylurate, w/ sleep efficiency and adlercreutzia added as covariates

# %%
from rich.progress import track
from statsmodels.formula.api import ols
from statsmodels.stats.multitest import multipletests

def get_results(dependent_feature, independent_feature):
    """Get a single association for a specific combination of features."""
    # Define the formula using the provided dependent and independent variables
    activity_covariates = ' + '.join(activity_features)
    formula = f"{dependent_feature} ~ C(sex) + age + BMI_CALC + {activity_covariates} + {independent_feature} + sleep_efficiency + bacteria_actinobacteria_coriobacteriia_coriobacteriales_coriobacteriaceae_adlercreutzia"
    fitted = ols(formula, data=df).fit()

# + sleep_efficiency + bacteria_actinobacteria_coriobacteriia_coriobacteriales_coriobacteriaceae_adlercreutzia
    # Create a Series with the results
    result_series = pd.Series({
        "dependent_feature": dependent_feature,
        "independent_feature": independent_feature,
        "beta": fitted.params[independent_feature],
        "t_statistic": fitted.tvalues[independent_feature],
        "p": fitted.pvalues[independent_feature],
        "n": fitted.nobs
    })

    return result_series

# %%
df = sleep_merged

# Define your lists of features
dependent_features = ['metabolite_100004295'] # 2-piperidinone
#dependent_features = ['sleep_efficiency']
#independent_features = metabolite_features
independent_features = ['metabolite_100001399'] # 1,7-dimethylurate
#independent_features = ['metabolite_100004295']

# Initialize an empty list to store the results
all_results = []

# Iterate through all combinations of dependent and independent features
for dependent_feature in track(dependent_features, description="Dependent Features"):
    for independent_feature in independent_features:
        result = get_results(dependent_feature, independent_feature)
        all_results.append(result)

# concatenate each entry in all_results list and turn into a pandas DF
tests = pd.DataFrame(pd.concat(all_results, axis=1))
tests = tests.transpose()

# add the metabolite metadata and calculate corrected p-value, q
anns = get_snapshot("metabolomics_metadata").iloc[:, 0:8]
anns["independent_feature"] = "metabolite_" + anns.CHEMICAL_ID.astype(str)
tests = pd.merge(tests, anns, on="independent_feature")
tests["q"] = multipletests(tests["p"], method="fdr_bh")[1]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
tests
# Out:
#       dependent_feature   independent_feature     beta t_statistic         p  \
# 0  metabolite_100004295  metabolite_100001399 -0.04648    -2.21161  0.027115
#
#         n  CHEMICAL_ID          SUB_PATHWAY SUPER_PATHWAY   BIOCHEMICAL_NAME  \
# 0  1879.0    100001399  Xanthine Metabolism   Xenobiotics  1,7-dimethylurate
#
#           CAS    KEGG       HMDB  PUBCHEM         q
# 0  33868-03-0  C16356  HMDB11103  91611.0  0.027115

# %%
import seaborn as sns
import matplotlib.pyplot as plt

g = sns.lmplot(x="metabolite_100001399", y='metabolite_100004295',
                   data=sleep_merged, scatter_kws={'alpha':0.1}, ci=95, fit_reg=True, line_kws={'color': 'red'})
plt.title(f'Scatter Plot: 1,7-dimethylurate vs. 2-piperidinone')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

g = sns.lmplot(x="bacteria_actinobacteria_coriobacteriia_coriobacteriales_coriobacteriaceae_adlercreutzia", y='metabolite_100004295',
                   data=sleep_merged, scatter_kws={'alpha':0.1}, ci=95, fit_reg=True, line_kws={'color': 'red'})
plt.title(f'Scatter Plot: Adlercreutzia Abundance vs. 2-piperidinone')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

g = sns.lmplot(x='metabolite_100004295', y='sleep_efficiency',
                   data=sleep_merged, scatter_kws={'alpha':0.1}, ci=95, fit_reg=True, line_kws={'color': 'red'})
plt.title(f'Scatter Plot: 2-piperidinone vs. Sleep Efficiency')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

g = sns.lmplot(x="bacteria_actinobacteria_coriobacteriia_coriobacteriales_coriobacteriaceae_adlercreutzia", y='sleep_efficiency',
                   data=sleep_merged, scatter_kws={'alpha':0.1}, ci=95, fit_reg=True, line_kws={'color': 'red'})
plt.title(f'Scatter Plot: Adlercreutzia Abundance vs. sleep efficiency')
plt.show()

# %% [markdown]
# # 1,7-dimethylurate mediates Adlercreutzia abundance effect on sleep efficiency?

# %%
from rich.progress import track
from statsmodels.formula.api import ols
from statsmodels.stats.multitest import multipletests

def get_results(dependent_feature, independent_feature):
    """Get a single association for a specific combination of features."""
    # Define the formula using the provided dependent and independent variables
    activity_covariates = ' + '.join(activity_features)
    formula = f"{dependent_feature} ~ C(sex) + age + BMI_CALC + C(vendor) + {activity_covariates} + {independent_feature}"
    fitted = ols(formula, data=df).fit()
    
    # Create a Series with the results
    result_series = pd.Series({
        "dependent_feature": dependent_feature,
        "independent_feature": independent_feature,
        "beta": fitted.params[independent_feature],
        "t_statistic": fitted.tvalues[independent_feature],
        "p": fitted.pvalues[independent_feature],
        "n": fitted.nobs
    })

    return result_series

# %%
df = sleep_merged
#df = pd.read_csv('sleep_df.csv')

# Define your lists of features
dependent_features = ['sleep_efficiency']
independent_features = ['bacteria_actinobacteria_coriobacteriia_coriobacteriales_coriobacteriaceae_adlercreutzia']


# Initialize an empty list to store the results
all_results = []

# Iterate through all combinations of dependent and independent features
for dependent_feature in track(dependent_features, description="Dependent Features"):
    for independent_feature in independent_features:
        result = get_results(dependent_feature, independent_feature)
        all_results.append(result)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
# turn the all_results list into a pandas df
tests = pd.DataFrame(pd.concat(all_results, axis=1))
tests = tests.transpose()

# add the metabolite metadata and calculate corrected p-value, q
#anns = get_snapshot("metabolomics_metadata").iloc[:, 0:8]
#anns["dependent_feature"] = "metabolite_" + anns.CHEMICAL_ID.astype(str)
#tests = pd.merge(tests, anns, on="dependent_feature")
tests["q"] = multipletests(tests["p"], method="fdr_bh")[1]
tests.sort_values(by='q')
# Out:
#   dependent_feature                                independent_feature  \
# 0  sleep_efficiency  bacteria_actinobacteria_coriobacteriia_corioba...
#
#        beta t_statistic         p       n         q
# 0  0.000776     4.88805  0.000001  2178.0  0.000001

# %%
from rich.progress import track
from statsmodels.formula.api import ols
from statsmodels.stats.multitest import multipletests

def get_results(dependent_feature, independent_feature):
    """Get a single association for a specific combination of features."""
    # Define the formula using the provided dependent and independent variables
    activity_covariates = ' + '.join(activity_features)
    formula = f"{dependent_feature} ~ C(sex) + age + BMI_CALC + C(vendor) + {activity_covariates} + {independent_feature}"
    fitted = ols(formula, data=df).fit()
    
    # Create a Series with the results
    result_series = pd.Series({
        "dependent_feature": dependent_feature,
        "independent_feature": independent_feature,
        "beta": fitted.params[independent_feature],
        "t_statistic": fitted.tvalues[independent_feature],
        "p": fitted.pvalues[independent_feature],
        "n": fitted.nobs
    })

    return result_series

# %%
df = sleep_merged

# Define your lists of features
dependent_features = ['sleep_efficiency']
independent_features = ['metabolite_100001399']

# Initialize an empty list to store the results
all_results = []

# Iterate through all combinations of dependent and independent features
for dependent_feature in track(dependent_features, description="Dependent Features"):
    for independent_feature in independent_features:
        result = get_results(dependent_feature, independent_feature)
        all_results.append(result)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
# turn the all_results list into a pandas df
tests = pd.DataFrame(pd.concat(all_results, axis=1))
tests = tests.transpose()

# add the metabolite metadata and calculate corrected p-value, q
anns = get_snapshot("metabolomics_metadata").iloc[:, 0:8]
anns["independent_feature"] = "metabolite_" + anns.CHEMICAL_ID.astype(str)
tests = pd.merge(tests, anns, on="independent_feature")
tests["q"] = multipletests(tests["p"], method="fdr_bh")[1]
tests.sort_values(by='q')
# Out:
#   dependent_feature   independent_feature      beta t_statistic         p  \
# 0  sleep_efficiency  metabolite_100001399  0.001329     3.04639  0.002347
#
#         n  CHEMICAL_ID          SUB_PATHWAY SUPER_PATHWAY   BIOCHEMICAL_NAME  \
# 0  1987.0    100001399  Xanthine Metabolism   Xenobiotics  1,7-dimethylurate
#
#           CAS    KEGG       HMDB  PUBCHEM         q
# 0  33868-03-0  C16356  HMDB11103  91611.0  0.002347

# %%
from rich.progress import track
from statsmodels.formula.api import ols
from statsmodels.stats.multitest import multipletests

def get_results(dependent_feature, independent_feature):
    """Get a single association for a specific combination of features."""
    # Define the formula using the provided dependent and independent variables
    activity_covariates = ' + '.join(activity_features)
    formula = f"{dependent_feature} ~ C(sex) + age + BMI_CALC + C(vendor) + metabolite_100001399 + {activity_covariates} + {independent_feature}"
    fitted = ols(formula, data=df).fit()
    
    # Create a Series with the results
    result_series = pd.Series({
        "dependent_feature": dependent_feature,
        "independent_feature": independent_feature,
        "beta": fitted.params[independent_feature],
        "t_statistic": fitted.tvalues[independent_feature],
        "p": fitted.pvalues[independent_feature],
        "n": fitted.nobs
    })

    return result_series

# %%
df = sleep_merged

# Define your lists of features
dependent_features = ['sleep_efficiency']
independent_features = ['bacteria_actinobacteria_coriobacteriia_coriobacteriales_coriobacteriaceae_adlercreutzia']

# Initialize an empty list to store the results
all_results = []

# Iterate through all combinations of dependent and independent features
for dependent_feature in track(dependent_features, description="Dependent Features"):
    for independent_feature in independent_features:
        result = get_results(dependent_feature, independent_feature)
        all_results.append(result)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
# turn the all_results list into a pandas df
tests = pd.DataFrame(pd.concat(all_results, axis=1))
tests = tests.transpose()

# add the metabolite metadata and calculate corrected p-value, q
#anns = get_snapshot("metabolomics_metadata").iloc[:, 0:8]
#anns["dependent_feature"] = "metabolite_" + anns.CHEMICAL_ID.astype(str)
#tests = pd.merge(tests, anns, on="dependent_feature")
tests["q"] = multipletests(tests["p"], method="fdr_bh")[1]
tests.sort_values(by='q')
# Out:
#   dependent_feature                                independent_feature  \
# 0  sleep_efficiency  bacteria_actinobacteria_coriobacteriia_corioba...
#
#        beta t_statistic         p       n         q
# 0  0.000723    4.362058  0.000014  1987.0  0.000014

# %% [markdown]
# # What are all the metabolites (not just sleep associated ones) that adlercreutzia associates with?

# %%
from rich.progress import track
from statsmodels.formula.api import ols
from statsmodels.stats.multitest import multipletests

def get_results(dependent_feature, independent_feature):
    """Get a single association for a specific combination of features."""
    # Define the formula using the provided dependent and independent variables
    activity_covariates = ' + '.join(activity_features)
    formula = f"{dependent_feature} ~ C(sex) + age + BMI_CALC + C(vendor) + {activity_covariates} + {independent_feature}"
    fitted = ols(formula, data=df).fit()
    
    # Create a Series with the results
    result_series = pd.Series({
        "dependent_feature": dependent_feature,
        "independent_feature": independent_feature,
        "beta": fitted.params[independent_feature],
        "t_statistic": fitted.tvalues[independent_feature],
        "p": fitted.pvalues[independent_feature],
        "n": fitted.nobs
    })

    return result_series

# %%
df = sleep_merged

# Define your lists of features
dependent_features = metabolite_features
independent_features = ['bacteria_actinobacteria_coriobacteriia_coriobacteriales_coriobacteriaceae_adlercreutzia']

# Initialize an empty list to store the results
all_results = []

# Iterate through all combinations of dependent and independent features
for dependent_feature in track(dependent_features, description="Dependent Features"):
    for independent_feature in independent_features:
        result = get_results(dependent_feature, independent_feature)
        all_results.append(result)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
# turn the all_results list into a pandas df
tests = pd.DataFrame(pd.concat(all_results, axis=1))
tests = tests.transpose()

# add the metabolite metadata and calculate corrected p-value, q
anns = get_snapshot("metabolomics_metadata").iloc[:, 0:8]
anns["dependent_feature"] = "metabolite_" + anns.CHEMICAL_ID.astype(str)
tests = pd.merge(tests, anns, on="dependent_feature")
tests["q"] = multipletests(tests["p"], method="fdr_bh")[1]

# %%
# save the results to a csv
tests.to_csv('adlercreutzia_all_metabolites.csv', index=False)

# %%
all_metabolite_adlercreutzia = pd.read_csv('adlercreutzia_all_metabolites.csv')

# %% [markdown]
# ### Adlercreutzia associated with other piperine derivatives in addition to 2-piperidinone

# %%
all_metabolite_adlercreutzia[(all_metabolite_adlercreutzia.SUB_PATHWAY == 'Food Component/Plant') & (all_metabolite_adlercreutzia.q < 0.05)]
# Out:
#         dependent_feature                                independent_feature  \
# 377  metabolite_100001977  bacteria_actinobacteria_coriobacteriia_corioba...
# 413  metabolite_100002253  bacteria_actinobacteria_coriobacteriia_corioba...
# 463  metabolite_100004295  bacteria_actinobacteria_coriobacteriia_corioba...
# 691  metabolite_100015965  bacteria_actinobacteria_coriobacteriia_corioba...
# 692  metabolite_100015966  bacteria_actinobacteria_coriobacteriia_corioba...
# 694  metabolite_100015968  bacteria_actinobacteria_coriobacteriia_corioba...
# 729  metabolite_100020491  bacteria_actinobacteria_coriobacteriia_corioba...
# 730  metabolite_100020492  bacteria_actinobacteria_coriobacteriia_corioba...
#
#          beta  t_statistic             p       n  CHEMICAL_ID  \
# 377  0.014279     2.908660  3.666952e-03  2171.0    100001977
# 413  0.070888     7.568871  5.666931e-14  2053.0    100002253
# 463 -0.068918    -8.952143  7.524697e-19  2101.0    100004295
# ...

# %%
all_metabolite_adlercreutzia.BIOCHEMICAL_NAME.value_counts().index.sort_values().tolist()
# Out:
# ['(16 or 17)-methylstearate (a19:0 or i19:0)',
#  '(2 or 3)-decenoate (10:1n7 or n8)',
#  '(N(1) + N(8))-acetylspermidine',
#  '(R)-3-hydroxybutyrylcarnitine',
#  '(S)-3-hydroxybutyrylcarnitine',
#  '(S)-a-amino-omega-caprolactam',
#  '1,2-dilinoleoyl-GPC (18:2/18:2)',
#  '1,2-dipalmitoyl-GPC (16:0/16:0)',
#  '1,3-dimethylurate',
#  '1,5-anhydroglucitol (1,5-AG)',
#  '1,7-dimethylurate',
#  '1-(1-enyl-oleoyl)-2-docosahexaenoyl-GPE (P-18:1/22:6)*',
#  '1-(1-enyl-oleoyl)-GPC (P-18:1)*',
#  '1-(1-enyl-oleoyl)-GPE (P-18:1)*',
#  '1-(1-enyl-palmitoyl)-2-arachidonoyl-GPC (P-16:0/20:4)*',
#  '1-(1-enyl-palmitoyl)-2-arachidonoyl-GPE (P-16:0/20:4)*',
#  '1-(1-enyl-palmitoyl)-2-dihomo-linolenoyl-GPC (P-16:0/20:3)*',
#  '1-(1-enyl-palmitoyl)-2-docosahexaenoyl-GPC (P-16:0/22:6)*',
#  '1-(1-enyl-palmitoyl)-2-docosahexaenoyl-GPE (P-16:0/22:6)*',
#  '1-(1-enyl-palmitoyl)-2-linoleoyl-GPC (P-16:0/18:2)*',
#  '1-(1-enyl-palmitoyl)-2-linoleoyl-GPE (P-16:0/18:2)*',
# ...

# %% [markdown]
# # Does adlercreutzia associate with other caffeine derivatives?

# %%
adlercreutzia_xanthine = pd.read_csv('adlercreutzia_all_metabolites.csv')
adlercreutzia_xanthine = adlercreutzia_xanthine[adlercreutzia_xanthine.SUB_PATHWAY == 'Xanthine Metabolism'].sort_values(by='q')
adlercreutzia_xanthine
# Out:
#         dependent_feature                                independent_feature  \
# 292  metabolite_100001403  bacteria_actinobacteria_coriobacteriia_corioba...
# 290  metabolite_100001399  bacteria_actinobacteria_coriobacteriia_corioba...
# 180  metabolite_100000437  bacteria_actinobacteria_coriobacteriia_corioba...
# 288  metabolite_100001396  bacteria_actinobacteria_coriobacteriia_corioba...
# 293  metabolite_100001405  bacteria_actinobacteria_coriobacteriia_corioba...
# 291  metabolite_100001402  bacteria_actinobacteria_coriobacteriia_corioba...
# 94         metabolite_849  bacteria_actinobacteria_coriobacteriia_corioba...
# 184  metabolite_100000453  bacteria_actinobacteria_coriobacteriia_corioba...
# 182  metabolite_100000445  bacteria_actinobacteria_coriobacteriia_corioba...
# 289  metabolite_100001398  bacteria_actinobacteria_coriobacteriia_corioba...
# 235  metabolite_100001108  bacteria_actinobacteria_coriobacteriia_corioba...
# ...

# %%
adlercreutzia_xanthine_hits = adlercreutzia_xanthine[adlercreutzia_xanthine.q < 0.05].dependent_feature.tolist()
adlercreutzia_xanthine_anns = adlercreutzia_xanthine.BIOCHEMICAL_NAME.tolist()
adlercreutzia_xanthine_tuples = list(zip(adlercreutzia_xanthine_hits, adlercreutzia_xanthine_anns))

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame, and you want to plot each column against "sleep_efficiency"
for column in adlercreutzia_xanthine_tuples:
    g = sns.lmplot(x="bacteria_actinobacteria_coriobacteriia_coriobacteriales_coriobacteriaceae_adlercreutzia", y=column[0],
                   data=sleep_merged, scatter_kws={'alpha':0.1}, ci=95, fit_reg=True, line_kws={'color': 'red'})
    plt.title(f'Scatter Plot: Adlercreutzia Abundance vs {column[1]}')
    plt.show()

# %% [markdown]
# ### relevant papers
# A metabolomics sleep study, some caffeine and derivative hits:
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5897041/
#
# Bacterial xanthine N-demethylase enzymes, NdmABCDE:
# https://jbioleng.biomedcentral.com/articles/10.1186/s13036-022-00316-6
# Recent paper 2023. Engineer E coli to produce the expensive caffeine derivative 7-methylxanthine. 7-methylxanthine is showing promise as a drug to prevent myopia or halt its progression, and has been tested in animals and human children. It's difficult to chemically synthesize, hence the synbio approach.
# This is the uniprot website for NdmA https://www.uniprot.org/uniprotkb/H9N289/entry it has NCBI accession number so can BLAST
#
# Pseudomonas and Klebsiella pneumoniae shown to be able to metabolize xanthines? Interesting bc Pseudomonas aeruginosa and Klebsiella pneumoniae pop up in BLAST search of human cytochrome P450 enzyme CYP2A6 which turns paraxanthine to 1,7-dimethylurate.
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2704713/
#
# human gut microbe xanthine oxidase biochemical characterizations (old paper):
# https://www.sciencedirect.com/science/article/pii/S0021925818650112?via%3Dihub

# %% [markdown]
# # Is adlercreutzia associated with wine (wine as a proxy for resveratrol? resveratrol not measured in blood metabolome ☹️)?

# %%
diet = pd.read_csv('diet_assessments.csv')

# %%
diet['assessment:lifestyle:achohol_type:enum'].value_counts()
# Out:
# assessment:lifestyle:achohol_type:enum
# (2) Wine             3476
# (1) Beer             1037
# (3) Liquor            908
# (0) No preference     908
# Name: count, dtype: int64

# %%
diet['assessment:lifestyle:alcohol_drinks_a_day:enum'][(diet['assessment:lifestyle:achohol_type:enum'] == '(2) Wine') & (diet['assessment:diet:alcohol_preference:int'] == '(2) Wine')].hist()
# Out:
# <Axes: >

# %%
diet['assessment:diet:alcohol_preference:int'].value_counts()
# Out:
# assessment:diet:alcohol_preference:int
# (2) Wine                      2062
# (1) Beer                       593
# (7) I do not drink alcohol     553
# (3) Liquor                     537
# (5) No usual type              254
# (4) Other kind                  73
# (6) I do not know                7
# Name: count, dtype: int64

# %%
diet['assessment:lifestyle:alcohol_drinks_a_day:enum'].value_counts()
# Out:
# assessment:lifestyle:alcohol_drinks_a_day:enum
# (1) 1-2 drinks            4442
# (0) I do not drink        1135
# (2) 3-4 drinks             810
# (3) 5-6 drinks              90
# (4) More than 6 drinks      26
# Name: count, dtype: int64

# %%
diet.columns
# Out:
# Index(['public_client_id', 'vendor', 'days_in_program',
#        'days_since_first_call', 'days_since_first_draw', 'month', 'weekday',
#        'season', 'assessment:lifestyle:achohol_type:enum',
#        'assessment:diet:alcohol_preference:int',
#        'assessment:lifestyle:alcohol_days_a_week:enum',
#        'assessment:diet:freq_alcohol:int',
#        'assessment:lifestyle:breakfast:enum',
#        'assessment:diet:freq_breakfast:int',
#        'assessment:lifestyle:cruciferous_vegetables:enum',
#        'assessment:diet:freq_cruciferous_vegetables:int',
#        'assessment:lifestyle:snack:enum', 'assessment:diet:freq_snacking:int',
#        'assessment:lifestyle:fruits:enum',
#        'assessment:diet:freq_fresh_fruit:int',
#        'assessment:lifestyle:vegetables:enum',
#        'assessment:diet:freq_raw_vegetables_salad:int',
#        'assessment:lifestyle:sugary_drinks:enum',
#        'assessment:diet:freq_soft_drinks:int',
# ...

# %% [markdown]
# # Exported df for Causal Mediation Analysis in R Studio

# %%
#R df for adlercreutzia-dimethylurate-sleep_efficiency
df = sleep_merged.copy()

df = df.rename(columns={'metabolite_100001399': 'dimethylurate', 'bacteria_actinobacteria_coriobacteriia_coriobacteriales_coriobacteriaceae_adlercreutzia': 'adlercreutzia'})

df_droppedNan = df[['sleep_efficiency', 'dimethylurate', 'activities_activityCalories', 'activities_calories',
       'activities_distance', 'activities_elevation', 'activities_floors',
       'activities_minutesFairlyActive', 'activities_minutesLightlyActive',
       'activities_minutesSedentary', 'activities_minutesVeryActive',
       'activities_steps', 'BMI_CALC', 'vendor', 'age', 'sex', 'adlercreutzia']].dropna()

# %%
df_droppedNan.to_csv('adlercreutzia-dimethylurate-sleep_efficiency.csv', index=False)

# %%
#R df for adlercreutzia-2-piperidinone-sleep_efficiency
df = sleep_merged.copy()
df = df.rename(columns={'metabolite_100004295': 'piperidinone2', 'bacteria_actinobacteria_coriobacteriia_coriobacteriales_coriobacteriaceae_adlercreutzia': 'adlercreutzia'})

df_droppedNan = df[['sleep_efficiency', 'piperidinone2', 'activities_activityCalories', 'activities_calories',
       'activities_distance', 'activities_elevation', 'activities_floors',
       'activities_minutesFairlyActive', 'activities_minutesLightlyActive',
       'activities_minutesSedentary', 'activities_minutesVeryActive',
       'activities_steps', 'BMI_CALC', 'vendor', 'age', 'sex', 'adlercreutzia']].dropna()

# %%
df_droppedNan.to_csv('adlercreutzia-piperidinone2-sleep_efficiency.csv', index=False)

# %%
#R df for erys-cortisol-sleep_efficiency
df = sleep_merged.copy()
df = df.rename(columns={'metabolite_356': 'cortisol', 'bacteria_firmicutes_erysipelotrichi_erysipelotrichales_erysipelotrichaceae': 'erys'})

df_droppedNan = df[['sleep_efficiency', 'cortisol', 'activities_activityCalories', 'activities_calories',
       'activities_distance', 'activities_elevation', 'activities_floors',
       'activities_minutesFairlyActive', 'activities_minutesLightlyActive',
       'activities_minutesSedentary', 'activities_minutesVeryActive',
       'activities_steps', 'BMI_CALC', 'vendor', 'age', 'sex', 'erys']].dropna()

# %%
df_droppedNan.to_csv('erys-cortisol-sleep_efficiency.csv', index=False)

# %%
#R df for erys-cortisol-sleep_restlessDuration
df = sleep_merged.copy()
df = df.rename(columns={'metabolite_356': 'cortisol', 'bacteria_firmicutes_erysipelotrichi_erysipelotrichales_erysipelotrichaceae': 'erys'})

df_droppedNan = df[['sleep_restlessDuration', 'cortisol', 'activities_activityCalories', 'activities_calories',
       'activities_distance', 'activities_elevation', 'activities_floors',
       'activities_minutesFairlyActive', 'activities_minutesLightlyActive',
       'activities_minutesSedentary', 'activities_minutesVeryActive',
       'activities_steps', 'BMI_CALC', 'vendor', 'age', 'sex', 'erys']].dropna()

# %%
df_droppedNan.to_csv('erys-cortisol-sleep_restlessDuration.csv', index=False)
